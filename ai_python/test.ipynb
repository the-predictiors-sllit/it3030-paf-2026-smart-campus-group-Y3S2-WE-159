# %%
testToken = "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6Ims1VE9fTHBkX2NKWVVlcHhwTjdsbiJ9.....UnJaOrd92cM5CV_ipdZkdRhesj7b6xNxj1qnVLMxyyH5ppKBr43frlTTPrFvRjkOs7GscE_SZ1YjTHGbEtTsGgxIcQxcmhxjMeE4IwH--tltyJJERBX1fNsG9nusOBZ9hIgMrbNvsBkPzcrStJ7zX-onoS5RLBsJSsKwYpe4aj7RR43YRQNdqsCy1OtoEFWGty4gLhQTMKolPB27YvPr5L6EMPLm7f3SJYCo6_3hVkad7T0PiTp64aQWBoAn3_laFq1L2q_iS0ADyVzi_F7VptCKOC_Bl6RPrnp2BKcUGtNI8_atOoS3p60i4iFgrdNxS_bI9zKctWMqJSNzT1YBGg"

# %%
import os
import requests


base_url = os.getenv("BACKEND_API_URL")
url = f"{base_url}/api/resources"

headers = {
    "Authorization": testToken,
    "Content-Type": "application/json",
}

# Making the request
response = requests.get(url, headers=headers, timeout=15)

# Checking if it worked
if response.status_code == 200:
    data = response.json()  # Parse JSON response into a Python dictionary
    print(data)
else:
    print(f"Failed! Status code: {response.status_code}")
    print(response.text)
# Out:
# {'_links': {'self': {'href': '/api/resources?page=1&limit=10'}}, 'data': {'items': [{'id': 'res_lab_03', 'name': 'Advanced Robotics', 'type': 'LAB', 'capacity': 15, 'location': 'Building 4, Basement', 'status': 'ACTIVE', '_links': {'self': {'href': '/api/resources/res_lab_03'}}}, {'id': 'res_lab_01', 'name': 'Chemistry Lab 3', 'type': 'LAB', 'capacity': 30, 'location': 'Building 2, Floor 1', 'status': 'ACTIVE', '_links': {'self': {'href': '/api/resources/res_lab_01'}}}, {'id': 'res_equip_03', 'name': 'DSLR Camera Kit', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'Media Room 4', 'status': 'OUT_OF_SERVICE', '_links': {'self': {'href': '/api/resources/res_equip_03'}}}, {'id': 'res_room_01', 'name': 'Main Lecture Hall A', 'type': 'ROOM', 'capacity': 150, 'location': 'Building 1, Floor 2', 'status': 'ACTIVE', '_links': {'self': {'href': '/api/resources/res_room_01'}}}, {'id': 'res_equip_01', 'name': 'Mobile Projector X1', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE', '_links': {'self': {'href': '/api/resources/res_equip_01'}}}, {'id': 'res_lab_02', 'name': 'Physics Lab Intro', 'type': 'LAB', 'capacity': 25, 'location': 'Building 2, Floor 2', 'status': 'ACTIVE', '_links': {'self': {'href': '/api/resources/res_lab_02'}}}, {'id': 'res_room_02', 'name': 'Seminar Room B', 'type': 'ROOM', 'capacity': 40, 'location': 'Building 1, Floor 3', 'status': 'ACTIVE', '_links': {'self': {'href': '/api/resources/res_room_02'}}}, {'id': 'res_room_03', 'name': 'Study Pod 1', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'ACTIVE', '_links': {'self': {'href': '/api/resources/res_room_03'}}}, {'id': 'res_room_04', 'name': 'Study Pod 2', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'OUT_OF_SERVICE', '_links': {'self': {'href': '/api/resources/res_room_04'}}}, {'id': 'res_equip_02', 'name': 'Wireless Mic Array A', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE', '_links': {'self': {'href': '/api/resources/res_equip_02'}}}], 'total': 10, 'page': 1, 'totalPages': 1}, 'error': None, 'status': 'success'}

# %%
{
    "_links": {"self": {"href": "/api/resources?page=1&limit=10"}},
    "data": {
        "items": [
            {
                "id": "res_lab_03",
                "name": "Advanced Robotics",
                "type": "LAB",
                "capacity": 15,
                "location": "Building 4, Basement",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_03"}},
            },
        ],
        "total": 10,
        "page": 1,
        "totalPages": 1,
    },
    "error": None,
    "status": "success",
}

# %%
data["data"]["items"]
# Out:
# [{'id': 'res_lab_03',
#   'name': 'Advanced Robotics',
#   'type': 'LAB',
#   'capacity': 15,
#   'location': 'Building 4, Basement',
#   'status': 'ACTIVE',
#   '_links': {'self': {'href': '/api/resources/res_lab_03'}}},
#  {'id': 'res_lab_01',
#   'name': 'Chemistry Lab 3',
#   'type': 'LAB',
#   'capacity': 30,
#   'location': 'Building 2, Floor 1',
#   'status': 'ACTIVE',
#   '_links': {'self': {'href': '/api/resources/res_lab_01'}}},
#  {'id': 'res_equip_03',
#   'name': 'DSLR Camera Kit',
#   'type': 'EQUIPMENT',
#   'capacity': None,
#   'location': 'Media Room 4',
#   'status': 'OUT_OF_SERVICE',
#   '_links': {'self': {'href': '/api/resources/res_equip_03'}}},
#  {'id': 'res_room_01',
#   'name': 'Main Lecture Hall A',
#   'type': 'ROOM',
#   'capacity': 150,
#   'location': 'Building 1, Floor 2',
#   'status': 'ACTIVE',
#   '_links': {'self': {'href': '/api/resources/res_room_01'}}},
#  {'id': 'res_equip_01',
#   'name': 'Mobile Projector X1',
#   'type': 'EQUIPMENT',
#   'capacity': None,
#   'location': 'IT Storage Desk',
#   'status': 'ACTIVE',
#   '_links': {'self': {'href': '/api/resources/res_equip_01'}}},
#  {'id': 'res_lab_02',
#   'name': 'Physics Lab Intro',
#   'type': 'LAB',
#   'capacity': 25,
#   'location': 'Building 2, Floor 2',
#   'status': 'ACTIVE',
#   '_links': {'self': {'href': '/api/resources/res_lab_02'}}},
#  {'id': 'res_room_02',
#   'name': 'Seminar Room B',
#   'type': 'ROOM',
#   'capacity': 40,
#   'location': 'Building 1, Floor 3',
#   'status': 'ACTIVE',
#   '_links': {'self': {'href': '/api/resources/res_room_02'}}},
#  {'id': 'res_room_03',
#   'name': 'Study Pod 1',
#   'type': 'ROOM',
#   'capacity': 4,
#   'location': 'Library, Floor 1',
#   'status': 'ACTIVE',
#   '_links': {'self': {'href': '/api/resources/res_room_03'}}},
#  {'id': 'res_room_04',
#   'name': 'Study Pod 2',
#   'type': 'ROOM',
#   'capacity': 4,
#   'location': 'Library, Floor 1',
#   'status': 'OUT_OF_SERVICE',
#   '_links': {'self': {'href': '/api/resources/res_room_04'}}},
#  {'id': 'res_equip_02',
#   'name': 'Wireless Mic Array A',
#   'type': 'EQUIPMENT',
#   'capacity': None,
#   'location': 'IT Storage Desk',
#   'status': 'ACTIVE',
#   '_links': {'self': {'href': '/api/resources/res_equip_02'}}}]

# %%
itemList = []
for item in data["data"]["items"]:
    formattedItem = {
        "id": item["id"],
        "name": item["name"],
        "type": item["type"],
        "capacity": item["capacity"],
        "location": item["location"],
        "status": item["status"],
    }
    itemList.append(formattedItem)
print(itemList)
# Out:
# [{'id': 'res_lab_03', 'name': 'Advanced Robotics', 'type': 'LAB', 'capacity': 15, 'location': 'Building 4, Basement', 'status': 'ACTIVE'}, {'id': 'res_lab_01', 'name': 'Chemistry Lab 3', 'type': 'LAB', 'capacity': 30, 'location': 'Building 2, Floor 1', 'status': 'ACTIVE'}, {'id': 'res_equip_03', 'name': 'DSLR Camera Kit', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'Media Room 4', 'status': 'OUT_OF_SERVICE'}, {'id': 'res_room_01', 'name': 'Main Lecture Hall A', 'type': 'ROOM', 'capacity': 150, 'location': 'Building 1, Floor 2', 'status': 'ACTIVE'}, {'id': 'res_equip_01', 'name': 'Mobile Projector X1', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}, {'id': 'res_lab_02', 'name': 'Physics Lab Intro', 'type': 'LAB', 'capacity': 25, 'location': 'Building 2, Floor 2', 'status': 'ACTIVE'}, {'id': 'res_room_02', 'name': 'Seminar Room B', 'type': 'ROOM', 'capacity': 40, 'location': 'Building 1, Floor 3', 'status': 'ACTIVE'}, {'id': 'res_room_03', 'name': 'Study Pod 1', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'ACTIVE'}, {'id': 'res_room_04', 'name': 'Study Pod 2', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'OUT_OF_SERVICE'}, {'id': 'res_equip_02', 'name': 'Wireless Mic Array A', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}]

# %%
for x in itemList:
    print(x)
# Out:
# {'id': 'res_lab_03', 'name': 'Advanced Robotics', 'type': 'LAB', 'capacity': 15, 'location': 'Building 4, Basement', 'status': 'ACTIVE'}
# {'id': 'res_lab_01', 'name': 'Chemistry Lab 3', 'type': 'LAB', 'capacity': 30, 'location': 'Building 2, Floor 1', 'status': 'ACTIVE'}
# {'id': 'res_equip_03', 'name': 'DSLR Camera Kit', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'Media Room 4', 'status': 'OUT_OF_SERVICE'}
# {'id': 'res_room_01', 'name': 'Main Lecture Hall A', 'type': 'ROOM', 'capacity': 150, 'location': 'Building 1, Floor 2', 'status': 'ACTIVE'}
# {'id': 'res_equip_01', 'name': 'Mobile Projector X1', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}
# {'id': 'res_lab_02', 'name': 'Physics Lab Intro', 'type': 'LAB', 'capacity': 25, 'location': 'Building 2, Floor 2', 'status': 'ACTIVE'}
# {'id': 'res_room_02', 'name': 'Seminar Room B', 'type': 'ROOM', 'capacity': 40, 'location': 'Building 1, Floor 3', 'status': 'ACTIVE'}
# {'id': 'res_room_03', 'name': 'Study Pod 1', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'ACTIVE'}
# {'id': 'res_room_04', 'name': 'Study Pod 2', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'OUT_OF_SERVICE'}
# {'id': 'res_equip_02', 'name': 'Wireless Mic Array A', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}

# %%
data = {
    "_links": {"self": {"href": "/api/resources?page=1&limit=10"}},
    "data": {
        "items": [
            {
                "id": "res_lab_03",
                "name": "Advanced Robotics",
                "type": "LAB",
                "capacity": 15,
                "location": "Building 4, Basement",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_03"}},
            },
            {
                "id": "res_lab_01",
                "name": "Chemistry Lab 3",
                "type": "LAB",
                "capacity": 30,
                "location": "Building 2, Floor 1",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_01"}},
            },
            {
                "id": "res_equip_03",
                "name": "DSLR Camera Kit",
                "type": "EQUIPMENT",
                "capacity": None,
                "location": "Media Room 4",
                "status": "OUT_OF_SERVICE",
                "_links": {"self": {"href": "/api/resources/res_equip_03"}},
            },
            {
                "id": "res_room_01",
                "name": "Main Lecture Hall A",
                "type": "ROOM",
                "capacity": 150,
                "location": "Building 1, Floor 2",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_room_01"}},
            },
            {
                "id": "res_equip_01",
                "name": "Mobile Projector X1",
                "type": "EQUIPMENT",
                "capacity": None,
                "location": "IT Storage Desk",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_equip_01"}},
            },
            {
                "id": "res_lab_02",
                "name": "Physics Lab Intro",
                "type": "LAB",
                "capacity": 25,
                "location": "Building 2, Floor 2",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_02"}},
            },
            {
                "id": "res_room_02",
                "name": "Seminar Room B",
                "type": "ROOM",
                "capacity": 40,
                "location": "Building 1, Floor 3",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_room_02"}},
            },
            {
                "id": "res_room_03",
                "name": "Study Pod 1",
                "type": "ROOM",
                "capacity": 4,
                "location": "Library, Floor 1",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_room_03"}},
            },
            {
                "id": "res_room_04",
                "name": "Study Pod 2",
                "type": "ROOM",
                "capacity": 4,
                "location": "Library, Floor 1",
                "status": "OUT_OF_SERVICE",
                "_links": {"self": {"href": "/api/resources/res_room_04"}},
            },
            {
                "id": "res_equip_02",
                "name": "Wireless Mic Array A",
                "type": "EQUIPMENT",
                "capacity": None,
                "location": "IT Storage Desk",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_equip_02"}},
            },
        ],
        "total": 10,
        "page": 1,
        "totalPages": 1,
    },
    "error": None,
    "status": "success",
}

# %%
itemList = []
for item in data["data"]["items"]:
    formattedItem = {
        "id": item["id"],
        "name": item["name"],
        "type": item["type"],
        "capacity": item["capacity"],
        "location": item["location"],
        "status": item["status"],
    }
    itemList.append(formattedItem)
print(itemList)
# Out:
# [{'id': 'res_lab_03', 'name': 'Advanced Robotics', 'type': 'LAB', 'capacity': 15, 'location': 'Building 4, Basement', 'status': 'ACTIVE'}, {'id': 'res_lab_01', 'name': 'Chemistry Lab 3', 'type': 'LAB', 'capacity': 30, 'location': 'Building 2, Floor 1', 'status': 'ACTIVE'}, {'id': 'res_equip_03', 'name': 'DSLR Camera Kit', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'Media Room 4', 'status': 'OUT_OF_SERVICE'}, {'id': 'res_room_01', 'name': 'Main Lecture Hall A', 'type': 'ROOM', 'capacity': 150, 'location': 'Building 1, Floor 2', 'status': 'ACTIVE'}, {'id': 'res_equip_01', 'name': 'Mobile Projector X1', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}, {'id': 'res_lab_02', 'name': 'Physics Lab Intro', 'type': 'LAB', 'capacity': 25, 'location': 'Building 2, Floor 2', 'status': 'ACTIVE'}, {'id': 'res_room_02', 'name': 'Seminar Room B', 'type': 'ROOM', 'capacity': 40, 'location': 'Building 1, Floor 3', 'status': 'ACTIVE'}, {'id': 'res_room_03', 'name': 'Study Pod 1', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'ACTIVE'}, {'id': 'res_room_04', 'name': 'Study Pod 2', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'OUT_OF_SERVICE'}, {'id': 'res_equip_02', 'name': 'Wireless Mic Array A', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}]

# %%
from thefuzz import fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re

# %%
# ── Sample product catalog ──────────────────────────────────────────
products = [
    {"id": 1, "name": "Canon multi color Projector v11.158"},
    {"id": 2, "name": "Epson Home Cinema 2350 Projector"},
    {"id": 3, "name": "BenQ 4K UHD Smart Projector TK860"},
    {"id": 4, "name": "Logitech MX Master 3 Wireless Mouse"},
    {"id": 5, "name": "Sony A7 IV Mirrorless Camera"},
    {"id": 6, "name": "Canon EOS R6 Mark II Camera"},
]

# %%
def normalize(text: str) -> str:
    text = text.lower().strip()  # to lower case
    text = re.sub(
        r"[^\w\s.]", " ", text
    )  # remove every thing that not is an letter, number, space,period
    text = re.sub(r"\s+", " ", text)  # remove white spaces
    return text

# %%
product_names = [p["name"] for p in products]
product_names
# Out:
# ['Canon multi color Projector v11.158',
#  'Epson Home Cinema 2350 Projector',
#  'BenQ 4K UHD Smart Projector TK860',
#  'Logitech MX Master 3 Wireless Mouse',
#  'Sony A7 IV Mirrorless Camera',
#  'Canon EOS R6 Mark II Camera']

# %%
vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4))
vectorizer
# Out:
# TfidfVectorizer(analyzer='char_wb', ngram_range=(2, 4))

# %%
tfidf_matrix = vectorizer.fit_transform([normalize(n) for n in product_names])

tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 479 stored elements and shape (6, 350)>

# %%
from thefuzz import fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re

products = [
    {"id": 1, "name": "Canon multi color Projector v11.158"},
    {"id": 2, "name": "Epson Home Cinema 2350 Projector"},
    {"id": 3, "name": "BenQ 4K UHD Smart Projector TK860"},
    {"id": 4, "name": "Logitech MX Master 3 Wireless Mouse"},
    {"id": 5, "name": "Sony A7 IV Mirrorless Camera"},
    {"id": 6, "name": "Canon EOS R6 Mark II Camera"},
]


def normalize(text: str) -> str:
    text = text.lower().strip()  # to lower case
    text = re.sub(
        r"[^\w\s.]", " ", text
    )  # remove every thing that not is an letter, number, space,period
    text = re.sub(r"\s+", " ", text)  # remove white spaces
    return text


product_names = [p["name"] for p in products]

vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4))

tfidf_matrix = vectorizer.fit_transform([normalize(n) for n in product_names])


def search(
    query: str, top_n: int = 3, threshold: int = 40, weights: dict | None = None
) -> list[dict]:
    """
    Returns up to top_n products whose combined score >= threshold.

    Weights control how much each scorer contributes (must sum to 1.0):
      fuzzy_ratio   - character-level edit distance
      token_sort    - word-order-agnostic token overlap
      partial_ratio - best substring match (helps with short queries)
      tfidf         - n-gram keyword similarity
    """

    if weights is None:
        weights = {
            "fuzzy_ratio": 0.30,
            "token_sort": 0.30,
            "partial_ratio": 0.20,
            "tfidf": 0.20,
        }

    norm_query = normalize(query)
    query_vec = vectorizer.transform([norm_query])
    tfidf_scores = cosine_similarity(query_vec, tfidf_matrix).flatten()

    results = []
    for i, product in enumerate(products):
        norm_name = normalize(product["name"])

        fr = fuzz.ratio(norm_query, norm_name)
        ts = fuzz.token_sort_ratio(norm_query, norm_name)
        pr = fuzz.partial_ratio(norm_query, norm_name)
        tf = tfidf_scores[i] * 100

        combined = (
            weights["fuzzy_ratio"] * fr
            + weights["token_sort"] * ts
            + weights["partial_ratio"] * pr
            + weights["tfidf"] * tf
        )

        if combined >= threshold:
            results.append(
                {
                    "product": product,
                    "score": round(combined, 1),
                    "detail": {
                        "fuzzy": fr,
                        "token_sort": ts,
                        "partial": pr,
                        "tfidf": round(tf, 1),
                    },
                }
            )
    results.sort(key=lambda x: x["score"], reverse=True)
    return results[:top_n]

# %%
search("projector")
# Out:
# [{'product': {'id': 1, 'name': 'Canon multi color Projector v11.158'}, 'score': np.float64(53.7), 'detail': {'fuzzy': 41, 'token_sort': 41, 'partial': 100, 'tfidf': np.float64(45.7)}}, {'product': {'id': 2, 'name': 'Epson Home Cinema 2350 Projector'}, 'score': np.float64(55.2), 'detail': {'fuzzy': 44, 'token_sort': 44, 'partial': 100, 'tfidf': np.float64(44.2)}}, {'product': {'id': 3, 'name': 'BenQ 4K UHD Smart Projector TK860'}, 'score': np.float64(54.4), 'detail': {'fuzzy': 43, 'token_sort': 43, 'partial': 100, 'tfidf': np.float64(43.0)}}]
# [{'product': {'id': 2, 'name': 'Epson Home Cinema 2350 Projector'},
#   'score': np.float64(55.2),
#   'detail': {'fuzzy': 44,
#    'token_sort': 44,
#    'partial': 100,
#    'tfidf': np.float64(44.2)}},
#  {'product': {'id': 3, 'name': 'BenQ 4K UHD Smart Projector TK860'},
#   'score': np.float64(54.4),
#   'detail': {'fuzzy': 43,
#    'token_sort': 43,
#    'partial': 100,
#    'tfidf': np.float64(43.0)}},
#  {'product': {'id': 1, 'name': 'Canon multi color Projector v11.158'},
#   'score': np.float64(53.7),
#   'detail': {'fuzzy': 41,
#    'token_sort': 41,
#    'partial': 100,
#    'tfidf': np.float64(45.7)}}]

# %% [markdown]
# ### applying this to my data

# %%
data = {
    "_links": {"self": {"href": "/api/resources?page=1&limit=10"}},
    "data": {
        "items": [
            {
                "id": "res_lab_03",
                "name": "Advanced Robotics",
                "type": "LAB",
                "capacity": 15,
                "location": "Building 4, Basement",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_03"}},
            },
            {
                "id": "res_lab_01",
                "name": "Chemistry Lab 3",
                "type": "LAB",
                "capacity": 30,
                "location": "Building 2, Floor 1",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_01"}},
            },
            {
                "id": "res_equip_03",
                "name": "DSLR Camera Kit",
                "type": "EQUIPMENT",
                "capacity": None,
                "location": "Media Room 4",
                "status": "OUT_OF_SERVICE",
                "_links": {"self": {"href": "/api/resources/res_equip_03"}},
            },
            {
                "id": "res_room_01",
                "name": "Main Lecture Hall A",
                "type": "ROOM",
                "capacity": 150,
                "location": "Building 1, Floor 2",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_room_01"}},
            },
            {
                "id": "res_equip_01",
                "name": "Mobile Projector X1",
                "type": "EQUIPMENT",
                "capacity": None,
                "location": "IT Storage Desk",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_equip_01"}},
            },
            {
                "id": "res_lab_02",
                "name": "Physics Lab Intro",
                "type": "LAB",
                "capacity": 25,
                "location": "Building 2, Floor 2",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_02"}},
            },
            {
                "id": "res_room_02",
                "name": "Seminar Room B",
                "type": "ROOM",
                "capacity": 40,
                "location": "Building 1, Floor 3",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_room_02"}},
            },
            {
                "id": "res_room_03",
                "name": "Study Pod 1",
                "type": "ROOM",
                "capacity": 4,
                "location": "Library, Floor 1",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_room_03"}},
            },
            {
                "id": "res_room_04",
                "name": "Study Pod 2",
                "type": "ROOM",
                "capacity": 4,
                "location": "Library, Floor 1",
                "status": "OUT_OF_SERVICE",
                "_links": {"self": {"href": "/api/resources/res_room_04"}},
            },
            {
                "id": "res_equip_02",
                "name": "Wireless Mic Array A",
                "type": "EQUIPMENT",
                "capacity": None,
                "location": "IT Storage Desk",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_equip_02"}},
            },
        ],
        "total": 10,
        "page": 1,
        "totalPages": 1,
    },
    "error": None,
    "status": "success",
}

# %%
itemList = []
for item in data["data"]["items"]:
    formattedItem = {
        "id": item["id"],
        "name": item["name"],
        "type": item["type"],
        "capacity": item["capacity"],
        "location": item["location"],
        "status": item["status"],
    }
    itemList.append(formattedItem)
print(itemList)
# Out:
# [{'id': 'res_lab_03', 'name': 'Advanced Robotics', 'type': 'LAB', 'capacity': 15, 'location': 'Building 4, Basement', 'status': 'ACTIVE'}, {'id': 'res_lab_01', 'name': 'Chemistry Lab 3', 'type': 'LAB', 'capacity': 30, 'location': 'Building 2, Floor 1', 'status': 'ACTIVE'}, {'id': 'res_equip_03', 'name': 'DSLR Camera Kit', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'Media Room 4', 'status': 'OUT_OF_SERVICE'}, {'id': 'res_room_01', 'name': 'Main Lecture Hall A', 'type': 'ROOM', 'capacity': 150, 'location': 'Building 1, Floor 2', 'status': 'ACTIVE'}, {'id': 'res_equip_01', 'name': 'Mobile Projector X1', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}, {'id': 'res_lab_02', 'name': 'Physics Lab Intro', 'type': 'LAB', 'capacity': 25, 'location': 'Building 2, Floor 2', 'status': 'ACTIVE'}, {'id': 'res_room_02', 'name': 'Seminar Room B', 'type': 'ROOM', 'capacity': 40, 'location': 'Building 1, Floor 3', 'status': 'ACTIVE'}, {'id': 'res_room_03', 'name': 'Study Pod 1', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'ACTIVE'}, {'id': 'res_room_04', 'name': 'Study Pod 2', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'OUT_OF_SERVICE'}, {'id': 'res_equip_02', 'name': 'Wireless Mic Array A', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}]

# %%
itemList = [i for i in itemList if i.get("type") == "LAB"]
itemList
# Out:
# [{'id': 'res_lab_03',
#   'name': 'Advanced Robotics',
#   'type': 'LAB',
#   'capacity': 15,
#   'location': 'Building 4, Basement',
#   'status': 'ACTIVE'},
#  {'id': 'res_lab_01',
#   'name': 'Chemistry Lab 3',
#   'type': 'LAB',
#   'capacity': 30,
#   'location': 'Building 2, Floor 1',
#   'status': 'ACTIVE'},
#  {'id': 'res_lab_02',
#   'name': 'Physics Lab Intro',
#   'type': 'LAB',
#   'capacity': 25,
#   'location': 'Building 2, Floor 2',
#   'status': 'ACTIVE'}]

# %%
itemList = [
    i for i in itemList if i.get("capacity") is not None and i["capacity"] >= 40
]
itemList
# Out:
# [{'id': 'res_room_01',
#   'name': 'Main Lecture Hall A',
#   'type': 'ROOM',
#   'capacity': 150,
#   'location': 'Building 1, Floor 2',
#   'status': 'ACTIVE'},
#  {'id': 'res_room_02',
#   'name': 'Seminar Room B',
#   'type': 'ROOM',
#   'capacity': 40,
#   'location': 'Building 1, Floor 3',
#   'status': 'ACTIVE'}]

# %%
{
    "id": "res_lab_03",
    "name": "Advanced Robotics",
    "type": "LAB",
    "capacity": 15,
    "location": "Building 4, Basement",
    "status": "ACTIVE",
}
# Out:
# {'id': 'res_lab_03',
#  'name': 'Advanced Robotics',
#  'type': 'LAB',
#  'capacity': 15,
#  'location': 'Building 4, Basement',
#  'status': 'ACTIVE'}

# %%
def searchByName(
    itemList: list,
    query: str,
    top_n: int = 3,
    threshold: int = 40,
    weights: dict | None = None,
) -> list[dict]:
    """
    Returns up to top_n products whose combined score >= threshold.

    Weights control how much each scorer contributes (must sum to 1.0):
    fuzzy_ratio   - character-level edit distance
    token_sort    - word-order-agnostic token overlap
    partial_ratio - best substring match (helps with short queries)
    tfidf         - n-gram keyword similarity
    """

    from thefuzz import fuzz
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.metrics.pairwise import cosine_similarity
    import re

    def normalize(text: str) -> str:
        text = text.lower().strip()  # to lower case
        text = re.sub(
            r"[^\w\s.]", " ", text
        )  # remove every thing that not is an letter, number, space,period
        text = re.sub(r"\s+", " ", text)  # remove white spaces
        return text

    original_string = [item["name"] for item in itemList]

    vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4))

    tfidf_matrix = vectorizer.fit_transform([normalize(n) for n in original_string])

    if weights is None:
        weights = {
            "fuzzy_ratio": 0.30,
            "token_sort": 0.30,
            "partial_ratio": 0.20,
            "tfidf": 0.20,
        }

    norm_query = normalize(query)
    query_vec = vectorizer.transform([norm_query])
    tfidf_scores = cosine_similarity(query_vec, tfidf_matrix).flatten()

    results = []
    for i, item in enumerate(itemList):
        norm_name = normalize(item["name"])

        fr = fuzz.ratio(norm_query, norm_name)
        ts = fuzz.token_sort_ratio(norm_query, norm_name)
        pr = fuzz.partial_ratio(norm_query, norm_name)
        tf = tfidf_scores[i] * 100

        combined = (
            weights["fuzzy_ratio"] * fr
            + weights["token_sort"] * ts
            + weights["partial_ratio"] * pr
            + weights["tfidf"] * tf
        )

        if combined >= threshold:
            results.append(
                {
                    "item": item,
                    "score": round(combined, 1),
                    "detail": {
                        "fuzzy": fr,
                        "token_sort": ts,
                        "partial": pr,
                        "tfidf": round(tf, 1),
                    },
                }
            )
    results.sort(key=lambda x: x["score"], reverse=True)
    return results[:top_n]

# %%
filtered_items = searchByName(query="lecture room", itemList=itemList)

# %%
[item["item"] for item in filtered_items]
# Out:
# [{'id': 'res_room_01',
#   'name': 'Main Lecture Hall A',
#   'type': 'ROOM',
#   'capacity': 150,
#   'location': 'Building 1, Floor 2',
#   'status': 'ACTIVE'},
#  {'id': 'res_room_02',
#   'name': 'Seminar Room B',
#   'type': 'ROOM',
#   'capacity': 40,
#   'location': 'Building 1, Floor 3',
#   'status': 'ACTIVE'}]

# %%
filtered_items
# Out:
# [{'item': {'id': 'res_room_01',
#    'name': 'Main Lecture Hall A',
#    'type': 'ROOM',
#    'capacity': 150,
#    'location': 'Building 1, Floor 2',
#    'status': 'ACTIVE'},
#   'score': np.float64(56.7),
#   'detail': {'fuzzy': 52,
#    'token_sort': 58,
#    'partial': 67,
#    'tfidf': np.float64(51.5)}},
#  {'item': {'id': 'res_room_02',
#    'name': 'Seminar Room B',
#    'type': 'ROOM',
#    'capacity': 40,
#    'location': 'Building 1, Floor 3',
#    'status': 'ACTIVE'},
#   'score': np.float64(46.7),
#   'detail': {'fuzzy': 54,
#    'token_sort': 38,
#    'partial': 60,
#    'tfidf': np.float64(35.7)}}]

# %%
def searchByLocation(
    itemList: list,
    query: str,
    top_n: int = 3,
    threshold: int = 40,
    weights: dict | None = None,
) -> list[dict]:
    """
    Returns up to top_n products whose combined score >= threshold.

    Weights control how much each scorer contributes (must sum to 1.0):
    fuzzy_ratio   - character-level edit distance
    token_sort    - word-order-agnostic token overlap
    partial_ratio - best substring match (helps with short queries)
    tfidf         - n-gram keyword similarity
    """

    from thefuzz import fuzz
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.metrics.pairwise import cosine_similarity
    import re

    def normalize(text: str) -> str:
        text = text.lower().strip()  # to lower case
        text = re.sub(
            r"[^\w\s.]", " ", text
        )  # remove every thing that not is an letter, number, space,period
        text = re.sub(r"\s+", " ", text)  # remove white spaces
        return text

    original_string = [item["location"] for item in itemList]

    vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4))

    tfidf_matrix = vectorizer.fit_transform([normalize(n) for n in original_string])

    if weights is None:
        weights = {
            "fuzzy_ratio": 0.30,
            "token_sort": 0.30,
            "partial_ratio": 0.20,
            "tfidf": 0.20,
        }

    norm_query = normalize(query)
    query_vec = vectorizer.transform([norm_query])
    tfidf_scores = cosine_similarity(query_vec, tfidf_matrix).flatten()

    results = []
    for i, item in enumerate(itemList):
        norm_name = normalize(item["location"])

        fr = fuzz.ratio(norm_query, norm_name)
        ts = fuzz.token_sort_ratio(norm_query, norm_name)
        pr = fuzz.partial_ratio(norm_query, norm_name)
        tf = tfidf_scores[i] * 100

        combined = (
            weights["fuzzy_ratio"] * fr
            + weights["token_sort"] * ts
            + weights["partial_ratio"] * pr
            + weights["tfidf"] * tf
        )

        if combined >= threshold:
            results.append(
                {
                    "product": item,
                    "score": round(combined, 1),
                    "detail": {
                        "fuzzy": fr,
                        "token_sort": ts,
                        "partial": pr,
                        "tfidf": round(tf, 1),
                    },
                }
            )
    results.sort(key=lambda x: x["score"], reverse=True)
    return results[:top_n]

# %%
searchByLocation(query="building 1", itemList=itemList)
# Out:
# [{'product': {'id': 'res_room_01',
#    'name': 'Main Lecture Hall A',
#    'type': 'ROOM',
#    'capacity': 150,
#    'location': 'Building 1, Floor 2',
#    'status': 'ACTIVE'},
#   'score': np.float64(78.3),
#   'detail': {'fuzzy': 71,
#    'token_sort': 71,
#    'partial': 100,
#    'tfidf': np.float64(78.6)}},
#  {'product': {'id': 'res_room_02',
#    'name': 'Seminar Room B',
#    'type': 'ROOM',
#    'capacity': 40,
#    'location': 'Building 1, Floor 3',
#    'status': 'ACTIVE'},
#   'score': np.float64(77.7),
#   'detail': {'fuzzy': 71,
#    'token_sort': 71,
#    'partial': 100,
#    'tfidf': np.float64(75.4)}},
#  {'product': {'id': 'res_lab_01',
#    'name': 'Chemistry Lab 3',
#    'type': 'LAB',
#    'capacity': 30,
#    'location': 'Building 2, Floor 1',
#    'status': 'ACTIVE'},
#   'score': np.float64(77.3),
#   'detail': {'fuzzy': 71,
#    'token_sort': 71,
#    'partial': 95,
#    'tfidf': np.float64(78.6)}}]

# %%
def searchByLocation(
    itemList: list,
    query: str,
    top_n: int = 3,
    threshold: int = 40,
    weights: dict | None = None,
) -> list[dict]:
    """
    Returns up to top_n products whose combined score >= threshold.

    Weights control how much each scorer contributes (must sum to 1.0):
    fuzzy_ratio   - character-level edit distance
    token_sort    - word-order-agnostic token overlap
    partial_ratio - best substring match (helps with short queries)
    tfidf         - n-gram keyword similarity
    """

    from thefuzz import fuzz
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.metrics.pairwise import cosine_similarity
    import re

    def normalize(text: str) -> str:
        text = text.lower().strip()  # to lower case
        text = re.sub(
            r"[^\w\s.]", " ", text
        )  # remove every thing that not is an letter, number, space,period
        text = re.sub(r"\s+", " ", text)  # remove white spaces
        return text

    original_string = [item["location"] for item in itemList]

    vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4))

    tfidf_matrix = vectorizer.fit_transform([normalize(n) for n in original_string])

    if weights is None:
        weights = {
            "fuzzy_ratio": 0.30,
            "token_sort": 0.30,
            "partial_ratio": 0.20,
            "tfidf": 0.20,
        }

    norm_query = normalize(query)
    query_vec = vectorizer.transform([norm_query])
    tfidf_scores = cosine_similarity(query_vec, tfidf_matrix).flatten()

    results = []
    for i, item in enumerate(itemList):
        norm_name = normalize(item["location"])

        fr = fuzz.ratio(norm_query, norm_name)
        ts = fuzz.token_sort_ratio(norm_query, norm_name)
        pr = fuzz.partial_ratio(norm_query, norm_name)
        tf = tfidf_scores[i] * 100

        combined = (
            weights["fuzzy_ratio"] * fr
            + weights["token_sort"] * ts
            + weights["partial_ratio"] * pr
            + weights["tfidf"] * tf
        )

        if combined >= threshold:
            results.append(
                {
                    "item": item,
                    "score": round(combined, 1),
                    "detail": {
                        "fuzzy": fr,
                        "token_sort": ts,
                        "partial": pr,
                        "tfidf": round(tf, 1),
                    },
                }
            )
    results.sort(key=lambda x: x["score"], reverse=True)
    return results[:top_n]


def searchByName(
    itemList: list,
    query: str,
    top_n: int = 3,
    threshold: int = 40,
    weights: dict | None = None,
) -> list[dict]:
    """
    Returns up to top_n products whose combined score >= threshold.

    Weights control how much each scorer contributes (must sum to 1.0):
    fuzzy_ratio   - character-level edit distance
    token_sort    - word-order-agnostic token overlap
    partial_ratio - best substring match (helps with short queries)
    tfidf         - n-gram keyword similarity
    """

    from thefuzz import fuzz
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.metrics.pairwise import cosine_similarity
    import re

    def normalize(text: str) -> str:
        text = text.lower().strip()  # to lower case
        text = re.sub(
            r"[^\w\s.]", " ", text
        )  # remove every thing that not is an letter, number, space,period
        text = re.sub(r"\s+", " ", text)  # remove white spaces
        return text

    original_string = [item["name"] for item in itemList]

    vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4))

    tfidf_matrix = vectorizer.fit_transform([normalize(n) for n in original_string])

    if weights is None:
        weights = {
            "fuzzy_ratio": 0.30,
            "token_sort": 0.30,
            "partial_ratio": 0.20,
            "tfidf": 0.20,
        }

    norm_query = normalize(query)
    query_vec = vectorizer.transform([norm_query])
    tfidf_scores = cosine_similarity(query_vec, tfidf_matrix).flatten()

    results = []
    for i, item in enumerate(itemList):
        norm_name = normalize(item["name"])

        fr = fuzz.ratio(norm_query, norm_name)
        ts = fuzz.token_sort_ratio(norm_query, norm_name)
        pr = fuzz.partial_ratio(norm_query, norm_name)
        tf = tfidf_scores[i] * 100

        combined = (
            weights["fuzzy_ratio"] * fr
            + weights["token_sort"] * ts
            + weights["partial_ratio"] * pr
            + weights["tfidf"] * tf
        )

        if combined >= threshold:
            results.append(
                {
                    "item": item,
                    "score": round(combined, 1),
                    "detail": {
                        "fuzzy": fr,
                        "token_sort": ts,
                        "partial": pr,
                        "tfidf": round(tf, 1),
                    },
                }
            )
    results.sort(key=lambda x: x["score"], reverse=True)
    return results[:top_n]


@tool
def campusResources(
    location: str = None,
    name: str = None,
    capacity: int = None,
    type: str = None,
):
    """
    Fetches a list of available campus resources (Labs, Rooms, Equipment, .etc).

    Use this tool when the user wants to browse resources, check availability,
    or find a specific location for their needs.

    Args:
        location: if there is location include here and it use a fuzzy search to filter details. if there is no locations keep this empty.
        name: if there is a resource name mentioned use this and this also use fuzzy search fo filter. if there is no locations keep this empty
        capacity: if user asked for a people capacity limit use this. this will filter content morethan of equal items. if there is noting mentions keep this empty.
        type: type of the resources. it only have these types (ROOM|LAB|EQUIPMENT)

    Returns:
        list: A list of resource objects if successful, or a string error message if the fetch fails.
    """
    import requests
    import json

    base_url = os.getenv("BACKEND_API_URL")
    url = f"{base_url}/api/resources"

    headers = {
        "Authorization": testToken,
        "Content-Type": "application/json",
    }

    try:
        response = requests.get(url, headers=headers, timeout=15)
        if response.status_code == 200:
            data = response.json()
            itemList = []
            for item in data["data"]["items"]:
                formattedItem = {
                    "id": item["id"],
                    "name": item["name"],
                    "type": item["type"],
                    "capacity": item["capacity"],
                    "location": item["location"],
                    "status": item["status"],
                }
                itemList.append(formattedItem)

            if name and location:
                name_ids = {
                    r["item"]["id"] for r in searchByName(query=name, itemList=itemList)
                }
                loc_ids = {
                    r["item"]["id"]
                    for r in searchByLocation(query=location, itemList=itemList)
                }
                matched_ids = name_ids & loc_ids
                itemList = [i for i in itemList if i["id"] in matched_ids]
            elif name:
                itemList = [
                    r["item"] for r in searchByName(query=name, itemList=itemList)
                ]
            elif location:
                itemList = [
                    r["item"]
                    for r in searchByLocation(query=location, itemList=itemList)
                ]
            if capacity:
                itemList = [
                    i
                    for i in itemList
                    if i.get("capacity") is not None and i["capacity"] >= capacity
                ]

            if type:
                itemList = [i for i in itemList if i.get("type") == type]

            # return itemList
            return json.dumps(itemList)

    except Exception as e:
        return f"Error accessing campus resources: {str(e)}"

# %% [markdown]
# better tool prompt

# %%
def searchByLocation(
    itemList: list,
    query: str,
    top_n: int = 3,
    threshold: int = 40,
    weights: dict | None = None,
) -> list[dict]:
    """
    Returns up to top_n items whose combined score >= threshold.

    Weights control how much each scorer contributes (must sum to 1.0):
    fuzzy_ratio   - character-level edit distance
    token_sort    - word-order-agnostic token overlap
    partial_ratio - best substring match (helps with short queries)
    tfidf         - n-gram keyword similarity
    """
    if not itemList:
        return []
    from thefuzz import fuzz
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.metrics.pairwise import cosine_similarity
    import re

    def normalize(text: str) -> str:
        text = text.lower().strip()  # to lower case
        text = re.sub(
            r"[^\w\s.]", " ", text
        )  # remove every thing that not is an letter, number, space,period
        text = re.sub(r"\s+", " ", text)  # remove white spaces
        return text

    original_string = [item["location"] for item in itemList]

    vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4))

    tfidf_matrix = vectorizer.fit_transform([normalize(n) for n in original_string])

    if weights is None:
        weights = {
            "fuzzy_ratio": 0.30,
            "token_sort": 0.30,
            "partial_ratio": 0.20,
            "tfidf": 0.20,
        }

    norm_query = normalize(query)
    query_vec = vectorizer.transform([norm_query])
    tfidf_scores = cosine_similarity(query_vec, tfidf_matrix).flatten()

    results = []
    for i, item in enumerate(itemList):
        norm_name = normalize(item["location"])

        fr = fuzz.ratio(norm_query, norm_name)
        ts = fuzz.token_sort_ratio(norm_query, norm_name)
        pr = fuzz.partial_ratio(norm_query, norm_name)
        tf = tfidf_scores[i] * 100

        combined = (
            weights["fuzzy_ratio"] * fr
            + weights["token_sort"] * ts
            + weights["partial_ratio"] * pr
            + weights["tfidf"] * tf
        )

        if combined >= threshold:
            results.append(
                {
                    "item": item,
                    "score": round(combined, 1),
                    "detail": {
                        "fuzzy": fr,
                        "token_sort": ts,
                        "partial": pr,
                        "tfidf": round(tf, 1),
                    },
                }
            )
    results.sort(key=lambda x: x["score"], reverse=True)
    return results[:top_n]


def searchByName(
    itemList: list,
    query: str,
    top_n: int = 3,
    threshold: int = 40,
    weights: dict | None = None,
) -> list[dict]:
    """
    Returns up to top_n items whose combined score >= threshold.

    Weights control how much each scorer contributes (must sum to 1.0):
    fuzzy_ratio   - character-level edit distance
    token_sort    - word-order-agnostic token overlap
    partial_ratio - best substring match (helps with short queries)
    tfidf         - n-gram keyword similarity
    """
    if not itemList:
        return []
    from thefuzz import fuzz
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.metrics.pairwise import cosine_similarity
    import re

    def normalize(text: str) -> str:
        text = text.lower().strip()  # to lower case
        text = re.sub(
            r"[^\w\s.]", " ", text
        )  # remove every thing that not is an letter, number, space,period
        text = re.sub(r"\s+", " ", text)  # remove white spaces
        return text

    original_string = [item["name"] for item in itemList]

    vectorizer = TfidfVectorizer(analyzer="char_wb", ngram_range=(2, 4))

    tfidf_matrix = vectorizer.fit_transform([normalize(n) for n in original_string])

    if weights is None:
        weights = {
            "fuzzy_ratio": 0.30,
            "token_sort": 0.30,
            "partial_ratio": 0.20,
            "tfidf": 0.20,
        }

    norm_query = normalize(query)
    query_vec = vectorizer.transform([norm_query])
    tfidf_scores = cosine_similarity(query_vec, tfidf_matrix).flatten()

    results = []
    for i, item in enumerate(itemList):
        norm_name = normalize(item["name"])

        fr = fuzz.ratio(norm_query, norm_name)
        ts = fuzz.token_sort_ratio(norm_query, norm_name)
        pr = fuzz.partial_ratio(norm_query, norm_name)
        tf = tfidf_scores[i] * 100

        combined = (
            weights["fuzzy_ratio"] * fr
            + weights["token_sort"] * ts
            + weights["partial_ratio"] * pr
            + weights["tfidf"] * tf
        )

        if combined >= threshold:
            results.append(
                {
                    "item": item,
                    "score": round(combined, 1),
                    "detail": {
                        "fuzzy": fr,
                        "token_sort": ts,
                        "partial": pr,
                        "tfidf": round(tf, 1),
                    },
                }
            )
    results.sort(key=lambda x: x["score"], reverse=True)
    return results[:top_n]


# @tool
def campusResources(
    location: str = None,
    name: str = None,
    capacity: int = None,
    type: str = None,
):
    """
    Retrieve campus resources such as rooms, labs, and equipment.

    Use this tool whenever the user asks about:
    - Finding or booking a room, lab, or piece of equipment
    - Checking what resources are available on campus
    - Searching for a resource by name or location
    - Filtering resources by capacity or type

    Args:
        name (str, optional):
            The name or partial name of the resource (e.g. "Chemistry Lab", "Lecture Hall").
            Uses fuzzy search — exact spelling not required.
            Leave empty if no specific resource name is mentioned.

        location (str, optional):
            A building, floor, or area to search within (e.g. "Building 2", "Library", "Floor 3").
            Uses fuzzy search — partial location names work fine.
            Leave empty if no location is mentioned.

        capacity (int, optional):
            Minimum number of people the resource must accommodate.
            Returns only resources with capacity >= this value.
            Leave empty if the user does not mention a group size or capacity requirement.

        type (str, optional):
            The category of resource. Must be one of:
                - "ROOM"      → meeting rooms, lecture halls, study pods
                - "LAB"       → science or computer labs
                - "EQUIPMENT" → projectors, cameras, microphones, etc.
            Leave empty if the user does not specify a type.

    Returns:
        str: A JSON string containing a list of matching resource objects, each with:
            id, name, type, capacity, location, and status.
            Returns an error message string if the request fails.

    Examples:
        User: "Find me a lab in Building 2"
            → name=None, location="Building 2", type="LAB"

        User: "Is there a room that fits 50 people?"
            → capacity=50, type="ROOM"

        User: "Show me all available equipment"
            → type="EQUIPMENT"

        User: "I need the Advanced Robotics lab"
            → name="Advanced Robotics", type="LAB"
    """
    import requests
    import json

    base_url = os.getenv("BACKEND_API_URL")
    url = f"{base_url}/api/resources"

    headers = {
        "Authorization": testToken,
        "Content-Type": "application/json",
    }

    try:
        response = requests.get(url, headers=headers, timeout=15)
        if response.status_code == 200:
            data = response.json()
            itemList = []
            for item in data["data"]["items"]:
                formattedItem = {
                    "id": item["id"],
                    "name": item["name"],
                    "type": item["type"],
                    "capacity": item["capacity"],
                    "location": item["location"],
                    "status": item["status"],
                }
                itemList.append(formattedItem)

            if name and location:
                name_ids = {
                    r["item"]["id"] for r in searchByName(query=name, itemList=itemList)
                }
                loc_ids = {
                    r["item"]["id"]
                    for r in searchByLocation(query=location, itemList=itemList)
                }
                matched_ids = name_ids & loc_ids
                itemList = [i for i in itemList if i["id"] in matched_ids]
            elif name:
                itemList = [
                    r["item"] for r in searchByName(query=name, itemList=itemList)
                ]
            elif location:
                itemList = [
                    r["item"]
                    for r in searchByLocation(query=location, itemList=itemList)
                ]
            if capacity:
                itemList = [
                    i
                    for i in itemList
                    if i.get("capacity") is not None and i["capacity"] >= capacity
                ]

            if type:
                itemList = [i for i in itemList if i.get("type") == type]

            # return itemList
            return json.dumps(itemList)

    except Exception as e:
        return f"Error accessing campus resources: {str(e)}"

# %%
x = ""

len(x)
# Out:
# 0

# %%
data = {
    "_links": {"self": {"href": "/api/resources?page=1&limit=10"}},
    "data": {
        "items": [
            {
                "id": "res_lab_03",
                "name": "Advanced Robotics",
                "type": "LAB",
                "capacity": 15,
                "location": "Building 4, Basement",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_03"}},
            },
            {
                "id": "res_lab_01",
                "name": "Chemistry Lab 3",
                "type": "LAB",
                "capacity": 30,
                "location": "Building 2, Floor 1",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_01"}},
            },
            {
                "id": "res_equip_03",
                "name": "DSLR Camera Kit",
                "type": "EQUIPMENT",
                "capacity": None,
                "location": "Media Room 4",
                "status": "OUT_OF_SERVICE",
                "_links": {"self": {"href": "/api/resources/res_equip_03"}},
            },
            {
                "id": "res_room_01",
                "name": "Main Lecture Hall A",
                "type": "ROOM",
                "capacity": 150,
                "location": "Building 1, Floor 2",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_room_01"}},
            },
            {
                "id": "res_equip_01",
                "name": "Mobile Projector X1",
                "type": "EQUIPMENT",
                "capacity": None,
                "location": "IT Storage Desk",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_equip_01"}},
            },
            {
                "id": "res_lab_02",
                "name": "Physics Lab Intro",
                "type": "LAB",
                "capacity": 25,
                "location": "Building 2, Floor 2",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_lab_02"}},
            },
            {
                "id": "res_room_02",
                "name": "Seminar Room B",
                "type": "ROOM",
                "capacity": 40,
                "location": "Building 1, Floor 3",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_room_02"}},
            },
            {
                "id": "res_room_03",
                "name": "Study Pod 1",
                "type": "ROOM",
                "capacity": 4,
                "location": "Library, Floor 1",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_room_03"}},
            },
            {
                "id": "res_room_04",
                "name": "Study Pod 2",
                "type": "ROOM",
                "capacity": 4,
                "location": "Library, Floor 1",
                "status": "OUT_OF_SERVICE",
                "_links": {"self": {"href": "/api/resources/res_room_04"}},
            },
            {
                "id": "res_equip_02",
                "name": "Wireless Mic Array A",
                "type": "EQUIPMENT",
                "capacity": None,
                "location": "IT Storage Desk",
                "status": "ACTIVE",
                "_links": {"self": {"href": "/api/resources/res_equip_02"}},
            },
        ],
        "total": 10,
        "page": 1,
        "totalPages": 1,
    },
    "error": None,
    "status": "success",
}

# %%
itemList = []
for item in data["data"]["items"]:
    formattedItem = {
        "id": item["id"],
        "name": item["name"],
        "type": item["type"],
        "capacity": item["capacity"],
        "location": item["location"],
        "status": item["status"],
    }
    itemList.append(formattedItem)
print(itemList)
# Out:
# [{'id': 'res_lab_03', 'name': 'Advanced Robotics', 'type': 'LAB', 'capacity': 15, 'location': 'Building 4, Basement', 'status': 'ACTIVE'}, {'id': 'res_lab_01', 'name': 'Chemistry Lab 3', 'type': 'LAB', 'capacity': 30, 'location': 'Building 2, Floor 1', 'status': 'ACTIVE'}, {'id': 'res_equip_03', 'name': 'DSLR Camera Kit', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'Media Room 4', 'status': 'OUT_OF_SERVICE'}, {'id': 'res_room_01', 'name': 'Main Lecture Hall A', 'type': 'ROOM', 'capacity': 150, 'location': 'Building 1, Floor 2', 'status': 'ACTIVE'}, {'id': 'res_equip_01', 'name': 'Mobile Projector X1', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}, {'id': 'res_lab_02', 'name': 'Physics Lab Intro', 'type': 'LAB', 'capacity': 25, 'location': 'Building 2, Floor 2', 'status': 'ACTIVE'}, {'id': 'res_room_02', 'name': 'Seminar Room B', 'type': 'ROOM', 'capacity': 40, 'location': 'Building 1, Floor 3', 'status': 'ACTIVE'}, {'id': 'res_room_03', 'name': 'Study Pod 1', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'ACTIVE'}, {'id': 'res_room_04', 'name': 'Study Pod 2', 'type': 'ROOM', 'capacity': 4, 'location': 'Library, Floor 1', 'status': 'OUT_OF_SERVICE'}, {'id': 'res_equip_02', 'name': 'Wireless Mic Array A', 'type': 'EQUIPMENT', 'capacity': None, 'location': 'IT Storage Desk', 'status': 'ACTIVE'}]

# %%
[
    {
        "id": "res_lab_03",
        "name": "Advanced Robotics",
        "type": "LAB",
        "capacity": 15,
        "location": "Building 4, Basement",
        "status": "ACTIVE",
    },
    {
        "id": "res_lab_01",
        "name": "Chemistry Lab 3",
        "type": "LAB",
        "capacity": 30,
        "location": "Building 2, Floor 1",
        "status": "ACTIVE",
    },
    {
        "id": "res_equip_03",
        "name": "DSLR Camera Kit",
        "type": "EQUIPMENT",
        "capacity": None,
        "location": "Media Room 4",
        "status": "OUT_OF_SERVICE",
    },
    {
        "id": "res_room_01",
        "name": "Main Lecture Hall A",
        "type": "ROOM",
        "capacity": 150,
        "location": "Building 1, Floor 2",
        "status": "ACTIVE",
    },
    {
        "id": "res_equip_01",
        "name": "Mobile Projector X1",
        "type": "EQUIPMENT",
        "capacity": None,
        "location": "IT Storage Desk",
        "status": "ACTIVE",
    },
    {
        "id": "res_lab_02",
        "name": "Physics Lab Intro",
        "type": "LAB",
        "capacity": 25,
        "location": "Building 2, Floor 2",
        "status": "ACTIVE",
    },
    {
        "id": "res_room_02",
        "name": "Seminar Room B",
        "type": "ROOM",
        "capacity": 40,
        "location": "Building 1, Floor 3",
        "status": "ACTIVE",
    },
    {
        "id": "res_room_03",
        "name": "Study Pod 1",
        "type": "ROOM",
        "capacity": 4,
        "location": "Library, Floor 1",
        "status": "ACTIVE",
    },
    {
        "id": "res_room_04",
        "name": "Study Pod 2",
        "type": "ROOM",
        "capacity": 4,
        "location": "Library, Floor 1",
        "status": "OUT_OF_SERVICE",
    },
    {
        "id": "res_equip_02",
        "name": "Wireless Mic Array A",
        "type": "EQUIPMENT",
        "capacity": None,
        "location": "IT Storage Desk",
        "status": "ACTIVE",
    },
]

# %%
itemList=[]

# %%
name = "Study area"
location = "library"

name_ids = {r["item"]["id"] for r in searchByName(query=name, itemList=itemList)}
print(name_ids)
loc_ids = {r["item"]["id"] for r in searchByLocation(query=location, itemList=itemList)}
print(loc_ids)
matched_ids = name_ids & loc_ids
itemList = [i for i in itemList if i["id"] in matched_ids]
# Out:
# set()
# set()

# %%
itemList
# Out:
# []

# %%
itemList
# Out:
# []

# %%
itemList
# Out:
# [{'id': 'res_room_01',
#   'name': 'Main Lecture Hall A',
#   'type': 'ROOM',
#   'capacity': 150,
#   'location': 'Building 1, Floor 2',
#   'status': 'ACTIVE'}]

# %%
[r["item"] for r in searchByName(query="", itemList=itemList)]
# Out:
# [{'id': 'res_equip_01',
#   'name': 'Mobile Projector X1',
#   'type': 'EQUIPMENT',
#   'capacity': None,
#   'location': 'IT Storage Desk',
#   'status': 'ACTIVE'}]

# %%
x  = " f f"
x.strip()
# Out:
# 'f f'
